# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\ASUS\\OneDrive\\Documents\\Desktop\\datasets_python\\dm_office_sales.csv")

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df["division"].unique()
# Out:
# array(['printers', 'peripherals', 'office supplies', 'computer hardware',
#        'computer software'], dtype=object)

# %%
df["level of education"].unique()
# Out:
# array(['some college', "associate's degree", 'high school',
#        "bachelor's degree", "master's degree"], dtype=object)

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x=df["salary"],y=df["sales"],hue=df["level of education"],alpha=1,palette="muted",size=df["level of education"])
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
len(df)
# Out:
# 1000

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
sns.rugplot(data=df,x="salary",height=1)
# Out:
# <Axes: xlabel='salary'>

# %%
sns.rugplot(data=df,y="level of education",height=1)
# Out:
# <Axes: ylabel='level of education'>

# %%
sns.rugplot(data=df,x="sales",height=1)
# Out:
# <Axes: xlabel='sales'>

# %%
sns.rugplot(data=df,y="sales",height=2)
# Out:
# <Axes: ylabel='sales'>

# %%
sns.rugplot(data=df,x="training level",height=1)
# Out:
# <Axes: xlabel='training level'>

# %%
sns.rugplot(data=df,y="training level",height=1)
# Out:
# <Axes: ylabel='training level'>

# %%
sns.displot(data=df,x="salary",kde="True",bins=10,color="Turquoise",linewidth=5,linestyle="-.",edgecolor="Lavender")

# %%
sns.kdeplot(data=df,x="salary",clip=(60000,100000))
# Out:
# <Axes: xlabel='salary', ylabel='Density'>

# %%
plt.figure(figsize=(8,8))
sns.countplot(data=df,x="division",hue="level of education")
# Out:
# <Axes: xlabel='division', ylabel='count'>
