# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\ASUS\\OneDrive\\Documents\\Desktop\\datasets_python\\Advertising.csv")

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#         TV  radio  newspaper  sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
df.head(7)
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8

# %%
df["total_spend"]=df["TV"]+df["radio"]+df["newspaper"]

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales  total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
sns.scatterplot(data=df,x="total_spend",y="sales")
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
sns.regplot(data=df,x="total_spend",y="sales")
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
np.polyfit(df["total_spend"],df["sales"],deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
np.polyfit(df["total_spend"],df["sales"],deg=2)
# Out:
# array([8.21901022e-06, 4.53486875e-02, 4.51143622e+00])

# %%
total_new_spend=np.linspace(0,500)

# %%
#y=b1*x+b0
sales_new=0.04868788*total_new_spend+4.24302822

# %%
sns.scatterplot(data=df,x="total_spend",y="sales")
plt.plot(total_new_spend,sales_new)

# %%
np.polyfit(df["total_spend"],df["sales"],deg=3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
sale_new2=3.07615033e-07*total_new_spend**3+-1.89392449e-04*total_new_spend**2+8.20886302e-02*total_new_spend+2.70495053e+00

# %%
sns.scatterplot(data=df,x="total_spend",y="sales")
plt.plot(total_new_spend,sale_new2,color="indigo")

# %%
total_new_spend2=800
pred_sale_new=3.07615033e-07*total_new_spend2**3+-1.89392449e-04*total_new_spend2**2+8.20886302e-02*total_new_spend2+2.70495053e+00

# %%
pred_sale_new
# Out:
# 104.66358422599998
